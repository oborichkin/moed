# %%
import sys
from random import random
sys.path.append('../')

# %%
from moed.model import Sequence, Model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
_range = range(1, 1000)

s1 = Model.linear(_range, 1, 0)
s2 = Sequence.from_func(_range, lambda x: random()*100)

# %%
s1.plot()
s2.plot()

# %%
s3 = s1 + s2
s3.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-aea2154b382c> in <module>
# ----> 1 s3 = s1 + s2
#       2 s3.plot()
#
# ~/Documents/moed/moed/model.py in __add__(self, other)
#      56         res = Sequence()
#      57         keys = list(set(self.x).union(other.x)).sort()
# ---> 58         for x in keys:
#      59             res._seq[x] = 0
#      60             if x in self.x:
#
# TypeError: 'NoneType' object is not iterable

# %%
s4 = s1 * s2
s4.plot()
