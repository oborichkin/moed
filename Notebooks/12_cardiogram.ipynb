# %%
import sys
from random import random
sys.path.append('../')

from moed.model import Sequence, Model
from moed.cardio import Cardiogram
from moed.analysis import Analysis
from moed.proc import Proc, Filter

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dots = 1000
freq = 10
dt = 0.005
interval = 200
relaxation = 15

# %%
c = Cardiogram(dots, freq, dt, interval, relaxation)
c.plot()
